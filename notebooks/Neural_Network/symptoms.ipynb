# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.metrics import Precision

# %%
def convert(df):
    mapping = {
        "yes": 1, "no": 0,
        "high": 2, "low": 1, "none": 0
    }
    
    for col in df.iloc[:, :12].columns:
        df[col] = df[col].map(mapping).fillna(df[col])  # Giữ nguyên giá trị nếu không có trong mapping
    
    return df

# %%
cols_to_drop = ['text', 'advanced_text', 'policy', 'antibiotics', 'self_empl', 'days_at_home', 
                'text_hist', 'text_phys_exam', 'advanced_text_hist','advanced_text_phys_exam',
                'phys_emb', 'adv_hist_emb', 'adv_phys_emb',
               ]

### File train 8000
train_df = pd.read_pickle('../../data/train_8000_final.p')
train_df = train_df.drop(columns=cols_to_drop, errors='ignore')  

### File test 2000
test_df = pd.read_pickle('../../data/test_2000_final.p')
test_df = test_df.drop(columns=cols_to_drop, errors='ignore') 

train_df = convert(train_df)
test_df = convert(test_df)

# Tạo nhãn kết hợp từ hai cột pneu và cold
count_values = train_df[['pneu', 'inf']].astype(str).agg('-'.join, axis=1)

# Kiểm tra số lượng mẫu mỗi nhóm nhãn
print(count_values.value_counts())
# Out:
# 0-0    6057
# 0-1    1856
# 1-0      56
# 1-1      31
# Name: count, dtype: int64

# %%
train_df.iloc[:, 7:12]
# Out:
#       dysp  cough  pain  fever  nasal
# 0        0      0     0      0      0
# 1        0      1     1      0      1
# 2        0      1     0      1      1
# 3        0      1     1      0      0
# 4        0      0     0      2      0
# ...    ...    ...   ...    ...    ...
# 7995     0      0     0      0      0
# 7996     1      0     0      0      0
# 7997     0      0     0      0      1
# 7998     0      1     0      0      1
# 7999     0      0     0      1      0
#
# [8000 rows x 5 columns]

# %%
def NN_model_train(target, df_train, df_test, emb='hist_emb'):
    
    # Chuyển embeddings từ dạng list thành numpy array
    X_train = np.array(df_train.iloc[:, 7:12].drop(columns=target, errors='ignore'))
    X_test = np.array(df_test.iloc[:, 7:12].drop(columns=target, errors='ignore'))

    """X_train = np.concatenate([X_train, df_train[emb].tolist()], axis=1)
    X_test = np.concatenate([X_test, df_test[emb].tolist()], axis=1)"""

    y_train = df_train[target].values  # Đảm bảo y_train là numpy array
    y_true = df_test[target].values  

    print("y_train shape:", y_train.shape)
    print("X_train: ", X_train.shape[1])
    # Định nghĩa model
    model = Sequential([
        Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(1, activation='relu')
    ])

    # Chọn loss function
    loss = 'binary_crossentropy'
    model.compile(optimizer=Adam(), loss=loss, metrics=['accuracy'])
    
    model.summary()

    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights = {0: class_weights[0], 1: class_weights[1]}

    print("Class Weights:", class_weights)

    # Huấn luyện mô hình
    model.fit(X_train, y_train, epochs=15, batch_size=100, validation_split=0.2, class_weight=class_weights)

    # Dự đoán trên tập kiểm tra
    y_pred = model.predict(X_test)

    # Bước 5: Tính ROC và PR Curve
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    pr_auc = auc(recall, precision)

    # Bước 6: Vẽ đồ thị
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve for " + target)
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(recall, precision, label=f"PR curve (AUC = {pr_auc:.2f})")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title("Precision-Recall Curve for " + target)
    plt.legend()
    
    plt.show()
    return model

# %%
import tensorflow as tf
import random

seeds = [327, 100, 105, 888, 521]

targets = ["pneu", "inf"]
for seed in seeds:
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    for i in targets:
        model = NN_model_train(i, train_df, test_df)
# Out:
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9212 - loss: 0.5993 - val_accuracy: 0.9125 - val_loss: 0.3943
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9083 - loss: 0.8780 - val_accuracy: 0.9125 - val_loss: 0.3816
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9274 - loss: 0.8700 - val_accuracy: 0.9638 - val_loss: 0.1827
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9422 - loss: 0.8503 - val_accuracy: 0.9325 - val_loss: 0.3784
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9130 - loss: 0.8524 - val_accuracy: 0.9112 - val_loss: 0.3905
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.8454 - val_accuracy: 0.9125 - val_loss: 0.4146
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9106 - loss: 0.8449 - val_accuracy: 0.9125 - val_loss: 0.4264
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9098 - loss: 0.8506 - val_accuracy: 0.9125 - val_loss: 0.3992
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9214 - loss: 0.9181 - val_accuracy: 0.9287 - val_loss: 0.6626
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9191 - loss: 0.9216 - val_accuracy: 0.8087 - val_loss: 1.1287
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8069 - loss: 1.1937 - val_accuracy: 0.9262 - val_loss: 0.8044
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9055 - loss: 1.0785 - val_accuracy: 0.9413 - val_loss: 0.2535
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9164 - loss: 0.8381 - val_accuracy: 0.9125 - val_loss: 0.3795
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9088 - loss: 0.8455 - val_accuracy: 0.9550 - val_loss: 0.2222
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9197 - loss: 0.8323 - val_accuracy: 0.9812 - val_loss: 0.0857
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7742 - loss: 1.1218 - val_accuracy: 0.8050 - val_loss: 0.3858
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8195 - loss: 0.4475 - val_accuracy: 0.8012 - val_loss: 0.4455
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8112 - loss: 0.4086 - val_accuracy: 0.8556 - val_loss: 0.3446
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8153 - loss: 0.4577 - val_accuracy: 0.8156 - val_loss: 0.3442
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8336 - loss: 0.3808 - val_accuracy: 0.8131 - val_loss: 0.3711
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8222 - loss: 0.4153 - val_accuracy: 0.8150 - val_loss: 0.3709
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8234 - loss: 0.3950 - val_accuracy: 0.8150 - val_loss: 0.3666
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8254 - loss: 0.3866 - val_accuracy: 0.8075 - val_loss: 0.4096
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8249 - loss: 0.4305 - val_accuracy: 0.8144 - val_loss: 0.3925
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8222 - loss: 0.4505 - val_accuracy: 0.8106 - val_loss: 0.4135
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8221 - loss: 0.4355 - val_accuracy: 0.8106 - val_loss: 0.4153
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8222 - loss: 0.4355 - val_accuracy: 0.8131 - val_loss: 0.4144
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8226 - loss: 0.4355 - val_accuracy: 0.8131 - val_loss: 0.4137
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8236 - loss: 0.4355 - val_accuracy: 0.8131 - val_loss: 0.4133
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8234 - loss: 0.4349 - val_accuracy: 0.8131 - val_loss: 0.4131
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9290 - loss: 0.5067 - val_accuracy: 0.9106 - val_loss: 0.5012
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9189 - loss: 0.4776 - val_accuracy: 0.9294 - val_loss: 0.3806
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9188 - loss: 0.4594 - val_accuracy: 0.9300 - val_loss: 0.4481
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9136 - loss: 0.4734 - val_accuracy: 0.9331 - val_loss: 0.3699
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9156 - loss: 0.4567 - val_accuracy: 0.9350 - val_loss: 0.4192
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9164 - loss: 0.5069 - val_accuracy: 0.9831 - val_loss: 0.0792
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9214 - loss: 0.4296 - val_accuracy: 0.9300 - val_loss: 0.3659
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9161 - loss: 0.4517 - val_accuracy: 0.9331 - val_loss: 0.3479
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9307 - loss: 0.4355 - val_accuracy: 0.9300 - val_loss: 0.3939
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9219 - loss: 0.4465 - val_accuracy: 0.9331 - val_loss: 0.3550
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9303 - loss: 0.4378 - val_accuracy: 0.9331 - val_loss: 0.3500
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9269 - loss: 0.4358 - val_accuracy: 0.9500 - val_loss: 0.3023
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9389 - loss: 0.4237 - val_accuracy: 0.9812 - val_loss: 0.0687
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9202 - loss: 0.4470 - val_accuracy: 0.9169 - val_loss: 0.4061
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9043 - loss: 0.4496 - val_accuracy: 0.9325 - val_loss: 0.3068
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                      │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7940 - loss: 0.6579 - val_accuracy: 0.8200 - val_loss: 0.4203
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8007 - loss: 0.4556 - val_accuracy: 0.7925 - val_loss: 0.4890
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7952 - loss: 0.4588 - val_accuracy: 0.8144 - val_loss: 0.3852
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8158 - loss: 0.4141 - val_accuracy: 0.8144 - val_loss: 0.3661
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8168 - loss: 0.4298 - val_accuracy: 0.8188 - val_loss: 0.3461
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8062 - loss: 0.4529 - val_accuracy: 0.8106 - val_loss: 0.3855
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8278 - loss: 0.4529 - val_accuracy: 0.7912 - val_loss: 0.5776
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8050 - loss: 0.4265 - val_accuracy: 0.8131 - val_loss: 0.3657
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8144 - loss: 0.4390 - val_accuracy: 0.8131 - val_loss: 0.3797
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8137 - loss: 0.4118 - val_accuracy: 0.8131 - val_loss: 0.3818
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8136 - loss: 0.4102 - val_accuracy: 0.8131 - val_loss: 0.3798
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8136 - loss: 0.4102 - val_accuracy: 0.8131 - val_loss: 0.3784
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8136 - loss: 0.4102 - val_accuracy: 0.8131 - val_loss: 0.3767
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8137 - loss: 0.4098 - val_accuracy: 0.8131 - val_loss: 0.3805
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8132 - loss: 0.4085 - val_accuracy: 0.8200 - val_loss: 0.3359
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9215 - loss: 0.7943 - val_accuracy: 0.9613 - val_loss: 0.1113
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9063 - loss: 0.5719 - val_accuracy: 0.9625 - val_loss: 0.3137
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9500 - loss: 0.6073 - val_accuracy: 0.9600 - val_loss: 0.2809
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9456 - loss: 0.6026 - val_accuracy: 0.9650 - val_loss: 0.2680
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9569 - loss: 0.5911 - val_accuracy: 0.9500 - val_loss: 0.2781
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9439 - loss: 0.5947 - val_accuracy: 0.9575 - val_loss: 0.3203
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9451 - loss: 0.6151 - val_accuracy: 0.9669 - val_loss: 0.2840
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9345 - loss: 0.6126 - val_accuracy: 0.9413 - val_loss: 0.3244
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9355 - loss: 0.6073 - val_accuracy: 0.9588 - val_loss: 0.3252
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9485 - loss: 0.5957 - val_accuracy: 0.9556 - val_loss: 0.2445
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9492 - loss: 0.5880 - val_accuracy: 0.9481 - val_loss: 0.3283
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9384 - loss: 0.5806 - val_accuracy: 0.9500 - val_loss: 0.3228
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9370 - loss: 0.5803 - val_accuracy: 0.9481 - val_loss: 0.2903
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9322 - loss: 0.5874 - val_accuracy: 0.9500 - val_loss: 0.2970
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9407 - loss: 0.6279 - val_accuracy: 0.9450 - val_loss: 0.2677
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                     │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7508 - loss: 0.7592 - val_accuracy: 0.8163 - val_loss: 0.3618
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8199 - loss: 0.4273 - val_accuracy: 0.8163 - val_loss: 0.3512
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8255 - loss: 0.4865 - val_accuracy: 0.8044 - val_loss: 0.4585
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8188 - loss: 0.4117 - val_accuracy: 0.8163 - val_loss: 0.3624
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8263 - loss: 0.4468 - val_accuracy: 0.8200 - val_loss: 0.3636
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8169 - loss: 0.4176 - val_accuracy: 0.8106 - val_loss: 0.3863
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8181 - loss: 0.3986 - val_accuracy: 0.8050 - val_loss: 0.3959
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8175 - loss: 0.3962 - val_accuracy: 0.8125 - val_loss: 0.3687
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8203 - loss: 0.3944 - val_accuracy: 0.8175 - val_loss: 0.3270
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8231 - loss: 0.4367 - val_accuracy: 0.8106 - val_loss: 0.4235
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8184 - loss: 0.4534 - val_accuracy: 0.8106 - val_loss: 0.4172
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8184 - loss: 0.4531 - val_accuracy: 0.8131 - val_loss: 0.4141
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8194 - loss: 0.4529 - val_accuracy: 0.8131 - val_loss: 0.4126
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8197 - loss: 0.4527 - val_accuracy: 0.8131 - val_loss: 0.4122
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8197 - loss: 0.4525 - val_accuracy: 0.8131 - val_loss: 0.4116
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                     │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9408 - loss: 1.1513 - val_accuracy: 0.9456 - val_loss: 0.1436
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9088 - loss: 0.5213 - val_accuracy: 0.9850 - val_loss: 0.0623
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9240 - loss: 0.5474 - val_accuracy: 0.9125 - val_loss: 0.2258
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8993 - loss: 0.3964 - val_accuracy: 0.9300 - val_loss: 0.2293
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9211 - loss: 0.4061 - val_accuracy: 0.9350 - val_loss: 0.2081
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9209 - loss: 0.4009 - val_accuracy: 0.9319 - val_loss: 0.2217
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9180 - loss: 0.4011 - val_accuracy: 0.9319 - val_loss: 0.2124
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9180 - loss: 0.4173 - val_accuracy: 0.9319 - val_loss: 0.2817
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9200 - loss: 0.4039 - val_accuracy: 0.9319 - val_loss: 0.2806
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9181 - loss: 0.4080 - val_accuracy: 0.9319 - val_loss: 0.2874
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9181 - loss: 0.4034 - val_accuracy: 0.9319 - val_loss: 0.2871
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9188 - loss: 0.4016 - val_accuracy: 0.9319 - val_loss: 0.2658
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9183 - loss: 0.4028 - val_accuracy: 0.9319 - val_loss: 0.3145
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9287 - loss: 0.3972 - val_accuracy: 0.9319 - val_loss: 0.3129
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9208 - loss: 0.3995 - val_accuracy: 0.9350 - val_loss: 0.2377
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                     │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7563 - loss: 1.0213 - val_accuracy: 0.8081 - val_loss: 0.3813
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8068 - loss: 0.4299 - val_accuracy: 0.8131 - val_loss: 0.3822
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8048 - loss: 0.4342 - val_accuracy: 0.8206 - val_loss: 0.3596
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8116 - loss: 0.4380 - val_accuracy: 0.8106 - val_loss: 0.3886
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8101 - loss: 0.4246 - val_accuracy: 0.8131 - val_loss: 0.4012
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8098 - loss: 0.4368 - val_accuracy: 0.8131 - val_loss: 0.4040
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8113 - loss: 0.4112 - val_accuracy: 0.8131 - val_loss: 0.3983
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8101 - loss: 0.4413 - val_accuracy: 0.8131 - val_loss: 0.4002
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8101 - loss: 0.4413 - val_accuracy: 0.8131 - val_loss: 0.3824
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8104 - loss: 0.4402 - val_accuracy: 0.8131 - val_loss: 0.3819
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8104 - loss: 0.4398 - val_accuracy: 0.8131 - val_loss: 0.3800
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8104 - loss: 0.4468 - val_accuracy: 0.8519 - val_loss: 0.3657
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7930 - loss: 0.4616 - val_accuracy: 0.8106 - val_loss: 0.4392
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8074 - loss: 0.4485 - val_accuracy: 0.8031 - val_loss: 0.4638
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7981 - loss: 0.4241 - val_accuracy: 0.8150 - val_loss: 0.3682
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                     │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9401 - loss: 0.8629 - val_accuracy: 0.9125 - val_loss: 0.4110
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8912 - loss: 0.4641 - val_accuracy: 0.9125 - val_loss: 0.4030
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8947 - loss: 0.3978 - val_accuracy: 0.9569 - val_loss: 0.1446
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9472 - loss: 0.3715 - val_accuracy: 0.9125 - val_loss: 0.3460
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9130 - loss: 0.5565 - val_accuracy: 0.9700 - val_loss: 0.1167
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9045 - loss: 0.3896 - val_accuracy: 0.9750 - val_loss: 0.0937
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9038 - loss: 0.4716 - val_accuracy: 0.8756 - val_loss: 0.3370
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8838 - loss: 0.3376 - val_accuracy: 0.9125 - val_loss: 0.3051
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8863 - loss: 0.3873 - val_accuracy: 0.9125 - val_loss: 0.3103
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8895 - loss: 0.3447 - val_accuracy: 0.9125 - val_loss: 0.3035
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8911 - loss: 0.3398 - val_accuracy: 0.9125 - val_loss: 0.3038
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8934 - loss: 0.3348 - val_accuracy: 0.9319 - val_loss: 0.2099
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9065 - loss: 0.3319 - val_accuracy: 0.9319 - val_loss: 0.2653
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9068 - loss: 0.3164 - val_accuracy: 0.9319 - val_loss: 0.2247
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9052 - loss: 0.3121 - val_accuracy: 0.9319 - val_loss: 0.2291
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_27 (Dense)                     │ (None, 256)                 │           1,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,049 (70.50 KB)
#  Trainable params: 18,049 (70.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7732 - loss: 1.2254 - val_accuracy: 0.7981 - val_loss: 0.4356
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8089 - loss: 0.4002 - val_accuracy: 0.8050 - val_loss: 0.3974
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8065 - loss: 0.4066 - val_accuracy: 0.8050 - val_loss: 0.4195
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8086 - loss: 0.4043 - val_accuracy: 0.8050 - val_loss: 0.4259
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8108 - loss: 0.4017 - val_accuracy: 0.8050 - val_loss: 0.4290
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8084 - loss: 0.4115 - val_accuracy: 0.7931 - val_loss: 0.4751
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7445 - loss: 0.6882 - val_accuracy: 0.8306 - val_loss: 0.4406
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8046 - loss: 0.4450 - val_accuracy: 0.8062 - val_loss: 0.4521
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8149 - loss: 0.4051 - val_accuracy: 0.8144 - val_loss: 0.3670
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8138 - loss: 0.3877 - val_accuracy: 0.8106 - val_loss: 0.3905
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8124 - loss: 0.3917 - val_accuracy: 0.8131 - val_loss: 0.3757
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8115 - loss: 0.3759 - val_accuracy: 0.8131 - val_loss: 0.3837
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8120 - loss: 0.3821 - val_accuracy: 0.8131 - val_loss: 0.3807
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8115 - loss: 0.3811 - val_accuracy: 0.8131 - val_loss: 0.3785
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8138 - loss: 0.3764 - val_accuracy: 0.8106 - val_loss: 0.3975
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
