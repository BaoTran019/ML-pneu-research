# %%
# !git clone https://github.com/prabaey/SynSUM.git
# Out:
# Cloning into 'SynSUM'...
# remote: Enumerating objects: 218, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 218 (delta 8), reused 7 (delta 4), pack-reused 202 (from 2)
# Receiving objects: 100% (218/218), 457.50 MiB | 36.83 MiB/s, done.
# Resolving deltas: 100% (84/84), done.
# Updating files: 100% (44/44), done.

# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_curve, auc, precision_recall_curve
import matplotlib.pyplot as plt

# %%
def convert(df):
    mapping = {
        "yes": 1, "no": 0,
        "high": 2, "low": 1, "none": 0
    }
    
    for col in df.iloc[:, :12].columns:
        df[col] = df[col].map(mapping).fillna(df[col])  # Giữ nguyên giá trị nếu không có trong mapping
    
    return df

# %%
cols_to_drop = ['text', 'advanced_text', 'policy', 'antibiotics', 'self_empl', 'days_at_home', 
                'text_hist', 'text_phys_exam', 'advanced_text_hist','advanced_text_phys_exam',
                'phys_emb', 'adv_hist_emb', 'adv_phys_emb',
               ]

### File train 8k
train_df = pd.read_pickle('/kaggle/input/diagnosis-of-pneumonia/concatenated_dataFileP.p')
train_df = train_df.drop(columns=cols_to_drop, errors='ignore')  

test_df = pd.read_pickle('/kaggle/working/SynSUM/data/emb/df_test_emb.p')
test_df = test_df.drop(columns=cols_to_drop, errors='ignore')  
#val_df = pd.read_pickle('/kaggle/working/SynSUM/data/emb/df_test_emb.p').drop(columns=cols_to_drop, errors='ignore')

train_df = convert(train_df)
test_df = convert(test_df)
#val_df = convert(val_df)
# Tạo nhãn kết hợp từ hai cột pneu và cold
count_values = train_df[['pneu', 'inf']].astype(str).agg('-'.join, axis=1)

# Kiểm tra số lượng mẫu mỗi nhóm nhãn
print(count_values.value_counts())
# Out:
# 0-0    6057
# 0-1    1856
# 1-0      56
# 1-1      31
# Name: count, dtype: int64

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.metrics import Precision


def NN_model_train(target, df_train, df_test, emb='hist_emb'):
    
    # Chuyển embeddings từ dạng list thành numpy array
    X_train = np.array(df_train[emb].tolist())
    X_test = np.array(df_test[emb].tolist())


    y_train = df_train[target].values  # Đảm bảo y_train là numpy array
    y_true = df_test[target].values  

    print("y_train shape:", y_train.shape)
    print("X_train: ", X_train.shape[1])
    # Định nghĩa model
    model = Sequential([
        Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(64, activation='relu'),
        Dense(1, activation='relu')
    ])

    # Chọn loss function
    loss = 'binary_crossentropy'
    model.compile(optimizer=Adam(), loss=loss, metrics=[Precision()])
    
    model.summary()

    class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
    class_weights = {0: class_weights[0], 1: class_weights[1]}

    print("Class Weights:", class_weights)

    # Huấn luyện mô hình
    model.fit(X_train, y_train, epochs=15, batch_size=100, validation_split=0.2, class_weight=class_weights)

    # Dự đoán trên tập kiểm tra
    y_pred = model.predict(X_test)

    # Bước 5: Tính ROC và PR Curve
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    precision, recall, _ = precision_recall_curve(y_true, y_pred)
    pr_auc = auc(recall, precision)

    # Bước 6: Vẽ đồ thị
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve for " + target)
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(recall, precision, label=f"PR curve (AUC = {pr_auc:.2f})")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title("Precision-Recall Curve for " + target)
    plt.legend()
    
    plt.show()
    return model

# %%
import tensorflow as tf
import random

seeds = [834, 123, 578, 592, 125]

targets = ["pneu", "inf"]
for seed in seeds:
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    for i in targets:
        model = NN_model_train(i, train_df, test_df)
# Out:
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 7.4166 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4165 - precision: 0.0000e+00 - val_loss: 0.1813 - val_precision: 0.0000e+00
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.6926 - precision_1: 0.3966 - val_loss: 0.5273 - val_precision_1: 0.5343
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5471 - precision_1: 0.4905 - val_loss: 0.4761 - val_precision_1: 0.5517
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4992 - precision_1: 0.5286 - val_loss: 0.4934 - val_precision_1: 0.5613
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4954 - precision_1: 0.5414 - val_loss: 0.4758 - val_precision_1: 0.5836
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4550 - precision_1: 0.5558 - val_loss: 0.4291 - val_precision_1: 0.5883
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4430 - precision_1: 0.5730 - val_loss: 0.4334 - val_precision_1: 0.5780
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4319 - precision_1: 0.5797 - val_loss: 0.4013 - val_precision_1: 0.6135
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4220 - precision_1: 0.5931 - val_loss: 0.4393 - val_precision_1: 0.5677
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4205 - precision_1: 0.5938 - val_loss: 0.3744 - val_precision_1: 0.6371
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4008 - precision_1: 0.5919 - val_loss: 0.4074 - val_precision_1: 0.6161
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3942 - precision_1: 0.6029 - val_loss: 0.3623 - val_precision_1: 0.6667
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3880 - precision_1: 0.6002 - val_loss: 0.4247 - val_precision_1: 0.5799
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4454 - precision_1: 0.6276 - val_loss: 0.4288 - val_precision_1: 0.6045
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4438 - precision_1: 0.5834 - val_loss: 0.4632 - val_precision_1: 0.5160
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4929 - precision_1: 0.4826 - val_loss: 0.7229 - val_precision_1: 0.3512
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.9428 - precision_2: 0.0216 - val_loss: 0.3003 - val_precision_2: 0.0577
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8142 - precision_2: 0.0395 - val_loss: 0.2133 - val_precision_2: 0.1429
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7329 - precision_2: 0.0769 - val_loss: 0.3270 - val_precision_2: 0.0664
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7876 - precision_2: 0.0707 - val_loss: 0.3311 - val_precision_2: 0.0657
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3896 - precision_2: 0.0624 - val_loss: 0.2327 - val_precision_2: 0.0936
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6479 - precision_2: 0.0750 - val_loss: 0.2308 - val_precision_2: 0.0920
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6118 - precision_2: 0.0986 - val_loss: 0.1911 - val_precision_2: 0.1159
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5900 - precision_2: 0.1155 - val_loss: 0.2902 - val_precision_2: 0.1046
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5603 - precision_2: 0.1238 - val_loss: 0.3124 - val_precision_2: 0.1032
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5431 - precision_2: 0.1274 - val_loss: 0.2870 - val_precision_2: 0.1231
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5244 - precision_2: 0.1578 - val_loss: 0.2707 - val_precision_2: 0.1391
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5096 - precision_2: 0.1735 - val_loss: 0.3022 - val_precision_2: 0.1290
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4999 - precision_2: 0.1814 - val_loss: 0.0720 - val_precision_2: 0.4286
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5618 - precision_2: 0.3333 - val_loss: 0.1813 - val_precision_2: 0.0000e+00
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4299 - precision_2: 0.0000e+00 - val_loss: 0.1813 - val_precision_2: 0.0000e+00
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                      │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.0534 - precision_3: 0.3978 - val_loss: 0.4660 - val_precision_3: 0.5788
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5814 - precision_3: 0.5182 - val_loss: 0.4627 - val_precision_3: 0.5651
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4727 - precision_3: 0.5329 - val_loss: 0.4293 - val_precision_3: 0.5771
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4674 - precision_3: 0.5598 - val_loss: 0.4255 - val_precision_3: 0.5814
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4491 - precision_3: 0.5692 - val_loss: 0.4481 - val_precision_3: 0.5762
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4455 - precision_3: 0.5705 - val_loss: 0.4537 - val_precision_3: 0.5923
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4275 - precision_3: 0.5827 - val_loss: 0.4530 - val_precision_3: 0.5722
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3965 - precision_3: 0.6002 - val_loss: 0.5386 - val_precision_3: 0.5446
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5227 - precision_3: 0.5985 - val_loss: 0.5844 - val_precision_3: 0.4437
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5288 - precision_3: 0.4315 - val_loss: 0.4550 - val_precision_3: 0.5617
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4469 - precision_3: 0.5367 - val_loss: 0.4487 - val_precision_3: 0.5614
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4237 - precision_3: 0.5649 - val_loss: 0.3670 - val_precision_3: 0.6487
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4253 - precision_3: 0.5890 - val_loss: 0.4197 - val_precision_3: 0.5931
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3997 - precision_3: 0.5874 - val_loss: 0.3835 - val_precision_3: 0.6401
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3921 - precision_3: 0.5876 - val_loss: 0.4047 - val_precision_3: 0.6325
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.1543 - precision_4: 0.0235 - val_loss: 0.1962 - val_precision_4: 0.1200
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6752 - precision_4: 0.0821 - val_loss: 0.8525 - val_precision_4: 0.0287
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4059 - precision_4: 0.0720 - val_loss: 0.7123 - val_precision_4: 0.0410
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5468 - precision_4: 0.0678 - val_loss: 0.4577 - val_precision_4: 0.0705
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4390 - precision_4: 0.0986 - val_loss: 0.4619 - val_precision_4: 0.0762
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4237 - precision_4: 0.1189 - val_loss: 0.4335 - val_precision_4: 0.0825
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4231 - precision_4: 0.1202 - val_loss: 0.3536 - val_precision_4: 0.1019
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4104 - precision_4: 0.1247 - val_loss: 0.3221 - val_precision_4: 0.1203
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4065 - precision_4: 0.1306 - val_loss: 0.2923 - val_precision_4: 0.1389
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3457 - precision_4: 0.1833 - val_loss: 0.3284 - val_precision_4: 0.1379
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3175 - precision_4: 0.2046 - val_loss: 0.5278 - val_precision_4: 0.1013
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3626 - precision_4: 0.1598 - val_loss: 0.4193 - val_precision_4: 0.1250
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3652 - precision_4: 0.1735 - val_loss: 0.3667 - val_precision_4: 0.1456
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3581 - precision_4: 0.1926 - val_loss: 0.1500 - val_precision_4: 0.1857
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4177 - precision_4: 0.1581 - val_loss: 0.0921 - val_precision_4: 0.2549
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                     │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.8370 - precision_5: 0.4061 - val_loss: 0.5244 - val_precision_5: 0.5261
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4846 - precision_5: 0.5338 - val_loss: 0.5214 - val_precision_5: 0.5178
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4611 - precision_5: 0.5553 - val_loss: 0.4379 - val_precision_5: 0.6064
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4908 - precision_5: 0.5091 - val_loss: 0.4343 - val_precision_5: 0.5873
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4304 - precision_5: 0.5968 - val_loss: 0.4735 - val_precision_5: 1.0000
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5723 - precision_5: 0.4522 - val_loss: 0.4937 - val_precision_5: 0.5518
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4762 - precision_5: 0.6008 - val_loss: 0.4523 - val_precision_5: 0.5777
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4217 - precision_5: 0.5785 - val_loss: 0.4118 - val_precision_5: 0.6100
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4171 - precision_5: 0.6071 - val_loss: 0.4136 - val_precision_5: 0.6230
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3969 - precision_5: 0.6103 - val_loss: 0.4032 - val_precision_5: 0.6423
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3833 - precision_5: 0.6139 - val_loss: 0.3788 - val_precision_5: 0.6450
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3832 - precision_5: 0.6246 - val_loss: 0.4021 - val_precision_5: 0.6250
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3740 - precision_5: 0.6199 - val_loss: 0.3756 - val_precision_5: 0.6483
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3656 - precision_5: 0.6572 - val_loss: 0.3915 - val_precision_5: 0.6429
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4124 - precision_5: 0.5928 - val_loss: 0.5813 - val_precision_5: 0.4545
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                     │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 1.5843 - precision_6: 0.0219 - val_loss: 0.5028 - val_precision_6: 0.0307
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4725 - precision_6: 0.0352 - val_loss: 0.4297 - val_precision_6: 0.0378
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3853 - precision_6: 0.0527 - val_loss: 0.1936 - val_precision_6: 0.1260
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3444 - precision_6: 0.0767 - val_loss: 0.1211 - val_precision_6: 0.2078
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2891 - precision_6: 0.0949 - val_loss: 0.0834 - val_precision_6: 0.2500
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2531 - precision_6: 0.1232 - val_loss: 0.1439 - val_precision_6: 0.1376
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2338 - precision_6: 0.1527 - val_loss: 0.0703 - val_precision_6: 0.2667
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2229 - precision_6: 0.1464 - val_loss: 0.0669 - val_precision_6: 0.3333
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2090 - precision_6: 0.1738 - val_loss: 0.1097 - val_precision_6: 0.2131
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1866 - precision_6: 0.1659 - val_loss: 0.1102 - val_precision_6: 0.2353
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1931 - precision_6: 0.1700 - val_loss: 0.0848 - val_precision_6: 0.3000
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1793 - precision_6: 0.1997 - val_loss: 0.1207 - val_precision_6: 0.1622
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1586 - precision_6: 0.2114 - val_loss: 0.0955 - val_precision_6: 0.2143
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1381 - precision_6: 0.2370 - val_loss: 0.0954 - val_precision_6: 0.2927
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1479 - precision_6: 0.2749 - val_loss: 0.6769 - val_precision_6: 0.0644
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                     │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.4791 - precision_7: 0.3490 - val_loss: 0.4930 - val_precision_7: 0.5517
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4874 - precision_7: 0.5289 - val_loss: 0.4458 - val_precision_7: 0.5965
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4710 - precision_7: 0.5809 - val_loss: 0.3868 - val_precision_7: 0.6326
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4346 - precision_7: 0.5939 - val_loss: 0.3773 - val_precision_7: 0.6395
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4178 - precision_7: 0.6072 - val_loss: 0.3469 - val_precision_7: 0.6521
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4125 - precision_7: 0.6146 - val_loss: 0.3569 - val_precision_7: 0.6503
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4042 - precision_7: 0.6168 - val_loss: 0.3525 - val_precision_7: 0.6615
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4161 - precision_7: 0.6226 - val_loss: 0.3562 - val_precision_7: 0.6573
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3784 - precision_7: 0.6256 - val_loss: 0.3620 - val_precision_7: 0.6776
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3938 - precision_7: 0.6413 - val_loss: 0.3248 - val_precision_7: 0.6952
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4812 - precision_7: 0.6407 - val_loss: 0.4157 - val_precision_7: 0.6443
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4249 - precision_7: 0.6099 - val_loss: 0.3743 - val_precision_7: 0.6464
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3722 - precision_7: 0.6312 - val_loss: 0.4280 - val_precision_7: 0.6158
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3732 - precision_7: 0.6287 - val_loss: 0.4346 - val_precision_7: 0.6354
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3589 - precision_7: 0.6408 - val_loss: 0.4257 - val_precision_7: 0.6330
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                     │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.5054972829521042, 1: 45.97701149425287}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.7148 - precision_8: 0.0223 - val_loss: 0.4390 - val_precision_8: 0.0325
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4886 - precision_8: 0.0344 - val_loss: 0.5282 - val_precision_8: 0.0328
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3917 - precision_8: 0.0424 - val_loss: 0.5981 - val_precision_8: 0.0402
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3750 - precision_8: 0.0569 - val_loss: 0.3257 - val_precision_8: 0.0613
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3198 - precision_8: 0.0741 - val_loss: 0.5537 - val_precision_8: 0.0449
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3013 - precision_8: 0.0817 - val_loss: 0.3109 - val_precision_8: 0.0842
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2493 - precision_8: 0.0999 - val_loss: 0.4326 - val_precision_8: 0.0777
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2320 - precision_8: 0.1184 - val_loss: 0.4930 - val_precision_8: 0.0721
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2215 - precision_8: 0.1239 - val_loss: 0.4330 - val_precision_8: 0.0865
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2283 - precision_8: 0.1251 - val_loss: 0.3479 - val_precision_8: 0.1103
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1921 - precision_8: 0.1498 - val_loss: 0.4031 - val_precision_8: 0.1019
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1903 - precision_8: 0.1595 - val_loss: 0.2382 - val_precision_8: 0.1171
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1601 - precision_8: 0.1904 - val_loss: 0.3214 - val_precision_8: 0.1190
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1728 - precision_8: 0.1639 - val_loss: 0.2996 - val_precision_8: 0.1197
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1551 - precision_8: 0.1857 - val_loss: 0.1980 - val_precision_8: 0.1512
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# y_train shape: (8000,)
# X_train:  768
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_27 (Dense)                     │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 213,377 (833.50 KB)
#  Trainable params: 213,377 (833.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Class Weights: {0: 0.6543432030099787, 1: 2.1197668256491786}
# Epoch 1/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.2589 - precision_9: 0.3719 - val_loss: 0.5604 - val_precision_9: 0.5197
# Epoch 2/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4877 - precision_9: 0.5185 - val_loss: 0.4402 - val_precision_9: 0.5897
# Epoch 3/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4740 - precision_9: 0.5685 - val_loss: 0.4126 - val_precision_9: 0.6030
# Epoch 4/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4358 - precision_9: 0.5658 - val_loss: 0.4858 - val_precision_9: 0.5744
# Epoch 5/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4513 - precision_9: 0.5748 - val_loss: 0.4045 - val_precision_9: 0.6143
# Epoch 6/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4472 - precision_9: 0.5712 - val_loss: 0.4498 - val_precision_9: 0.5872
# Epoch 7/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4391 - precision_9: 0.5773 - val_loss: 0.5090 - val_precision_9: 0.5372
# Epoch 8/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4614 - precision_9: 0.5994 - val_loss: 0.4831 - val_precision_9: 0.5978
# Epoch 9/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4154 - precision_9: 0.5904 - val_loss: 0.4000 - val_precision_9: 0.6200
# Epoch 10/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5504 - precision_9: 0.5815 - val_loss: 0.9258 - val_precision_9: 0.2988
# Epoch 11/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5490 - precision_9: 0.4308 - val_loss: 0.5137 - val_precision_9: 0.5692
# Epoch 12/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4567 - precision_9: 0.5600 - val_loss: 0.4300 - val_precision_9: 0.6015
# Epoch 13/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4217 - precision_9: 0.5682 - val_loss: 0.3770 - val_precision_9: 0.6347
# Epoch 14/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9101 - precision_9: 0.5593 - val_loss: 0.5071 - val_precision_9: 0.5531
# Epoch 15/15
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5159 - precision_9: 0.5237 - val_loss: 0.5205 - val_precision_9: 0.5219
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
