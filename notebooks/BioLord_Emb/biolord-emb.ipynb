# %%
import pandas as pd

# %%
df = pd.read_excel('../../data/File_10000_final.xlsx')

# %%
df
# Out:
#      policy self_empl asthma smoking COPD  season hay_fever pneu cold dysp  \
# 0       yes        no     no      no   no  summer        no   no   no   no
# 1       yes        no     no      no   no  summer        no   no   no   no
# 2       yes        no     no      no   no  summer        no   no   no   no
# 3        no       yes     no      no   no  summer       yes   no   no   no
# 4       yes        no     no      no   no  winter        no   no   no   no
# ...     ...       ...    ...     ...  ...     ...       ...  ...  ...  ...
# 9995     no        no     no      no   no  summer        no   no   no  yes
# 9996     no        no     no      no   no  summer        no   no   no   no
# 9997     no        no     no      no   no  summer        no   no   no   no
# 9998    yes       yes     no      no   no  winter        no   no   no   no
# 9999    yes        no     no      no   no  winter        no   no  yes   no
#
#      cough pain fever nasal antibiotics  days_at_home  \
# ...

# %%
from sentence_transformers import SentenceTransformer

# Load model (dùng BERT hoặc một mô hình khác)
model = SentenceTransformer('FremyCompany/BioLORD-2023')

# Chuyển sang embedding
df['BioLORD emb'] = str(model.encode(df['text'].tolist()))
# Out:
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]

# %%
df
# Out:
#      policy self_empl asthma smoking COPD  season hay_fever pneu cold dysp  \
# 0       yes        no     no      no   no  summer        no   no   no   no
# 1       yes        no     no      no   no  summer        no   no   no   no
# 2       yes        no     no      no   no  summer        no   no   no   no
# 3        no       yes     no      no   no  summer       yes   no   no   no
# 4       yes        no     no      no   no  winter        no   no   no   no
# ...     ...       ...    ...     ...  ...     ...       ...  ...  ...  ...
# 9995     no        no     no      no   no  summer        no   no   no  yes
# 9996     no        no     no      no   no  summer        no   no   no   no
# 9997     no        no     no      no   no  summer        no   no   no   no
# 9998    yes       yes     no      no   no  winter        no   no   no   no
# 9999    yes        no     no      no   no  winter        no   no  yes   no
#
#      cough pain fever nasal antibiotics  days_at_home  \
# ...
